# %% [markdown]
# # Student Performance Project

# %% [markdown]
# # Objectives

# %% [markdown]
# ### 1. To determine if the parental level of education affect the performance of students

# %% [markdown]
# ### 2. To determine the effect of lunch on the performance of students

# %% [markdown]
# ### 3. How test preparation influence the performance of students

# %% [markdown]
# # import some importance libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Data Set

# %%
Student_Performance=pd.read_csv("Student Performance Dataset.csv")
Student_Performance
# Out:
#      Gender Race/ethnicity Parental level of education         Lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     Test preparation course  Math score  Reading score  Writing score
# ...

# %% [markdown]
# # Exploration and Cleaning of Dataset

# %% [markdown]
# ## Checking the data information

# %%
Student_Performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       1000 non-null   object
#  1   Race/ethnicity               1000 non-null   object
#  2   Parental level of education  1000 non-null   object
#  3   Lunch                        1000 non-null   object
#  4   Test preparation course      1000 non-null   object
#  5   Math score                   1000 non-null   int64
#  6   Reading score                1000 non-null   int64
#  7   Writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# #### The dataset contains 1000 entries with 8 columns.

# %% [markdown]
# ### Checking the missing values

# %%
Student_Performance.isnull().sum()
# Out:
# Gender                         0
# Race/ethnicity                 0
# Parental level of education    0
# Lunch                          0
# Test preparation course        0
# Math score                     0
# Reading score                  0
# Writing score                  0
# dtype: int64

# %% [markdown]
# ### There is no missing values in the dataset.

# %% [markdown]
# #### To check if there is duplicate value in the data

# %%
Student_Performance.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### There is no duplicated values in the data.

# %% [markdown]
# # Analysis

# %%
# Data summary of the data

# %%
Student_Performance.describe()
# Out:
#        Math score  Reading score  Writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# To check the highest scores of the student in three subjects.

# %%
Student_Performance[["Math score","Reading score","Writing score"]].max()
# Out:
# Math score       100
# Reading score    100
# Writing score    100
# dtype: int64

# %%
# To check the lowest scores of the students in three subjects.

# %%
Student_Performance[["Math score","Reading score","Writing score"]].min()
# Out:
# Math score        0
# Reading score    17
# Writing score    10
# dtype: int64

# %%
Student_Performance[["Math score","Reading score","Writing score"]].count()
# Out:
# Math score       1000
# Reading score    1000
# Writing score    1000
# dtype: int64

# %%
Student_Performance[["Gender","Race/ethnicity","Parental level of education","Lunch","Test preparation course"]].max()
# Out:
# Gender                                     male
# Race/ethnicity                          group E
# Parental level of education    some high school
# Lunch                                  standard
# Test preparation course                    none
# dtype: object

# %%
# To know the number of female students

# %%
Female=Student_Performance[Student_Performance["Gender"]== 'female']['Gender'].count()
print(f' The number of female students is {Female}')
# Out:
#  The number of female students is 518

# %%
# To know the number of male students

# %%
Male=Student_Performance[Student_Performance["Gender"]== 'male']['Gender'].count()
print( f' The number of male students is {Male}')
# Out:
#  The number of male students is 482

# %%
Parental_level_of_education_count=Student_Performance["Parental level of education"].value_counts()
Parental_level_of_education_count
# Out:
# Parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# # Report on Student Performance Visualization
# The dataset analyzed comprises students performance categorized by Gender, Parental Level of Education, Lunch type and Test preparation course, and thier respective scores in Math, Reading and writing. This report summarizes the insights obtained from the bar chart created to visualize this data.

# %% [markdown]
# # Data Visualization

# %%
Student_Performance.head()
# Out:
#    Gender Race/ethnicity Parental level of education         Lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   Test preparation course  Math score  Reading score  Writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
BarChart=Parental_level_of_education_count.plot(kind='bar',title='Parental level of education', ylabel='Value',color='green')

# %%
Race_ethnicity_count=Student_Performance["Race/ethnicity"].value_counts()
Race_ethnicity_count
# Out:
# Race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
Race_ethnicity_count.plot(kind='bar', title='Race', color='purple')
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(data=Student_Performance, x='Reading score', bins=10, kde=True)
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Student_Performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       1000 non-null   object
#  1   Race/ethnicity               1000 non-null   object
#  2   Parental level of education  1000 non-null   object
#  3   Lunch                        1000 non-null   object
#  4   Test preparation course      1000 non-null   object
#  5   Math score                   1000 non-null   int64
#  6   Reading score                1000 non-null   int64
#  7   Writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
import seaborn as sns

# %%
# Set the sytle
sns.set(style="whitegrid")

# Initialze the matplotlib figure
fig, axes= plt.subplots(3,2,figsize=(14,18))
# Gender Vs Scores
sns.barplot(x="Gender", y="Math score", data=Student_Performance, ax=axes[0,0])
axes[0,0].set_title("Math Score by Gender")

sns.barplot(x="Gender", y="Reading score", data=Student_Performance, ax=axes[0,1])
axes[0,1].set_title("Reading Score by Gender")

sns.barplot(x="Gender", y="Writing score", data=Student_Performance, ax=axes[1,0])
axes[1,0].set_title("Writing Score by Gender")

# Parential Level of education vs Scores
sns.barplot(x="Parental level of education", y="Math score", data=Student_Performance, ax=axes[1,1])
axes[1,1].set_title("Math Score by Parental Level of Education")
axes[1,1].tick_params(axis='x', rotation=90)

sns.barplot(x="Parental level of education", y="Reading score", data=Student_Performance, ax=axes[2,0])
axes[2,0].set_title("Reading Score by Parental Level of Education")
axes[2,0].tick_params(axis='x', rotation=90)

sns.barplot(x="Parental level of education", y="Writing score", data=Student_Performance, ax=axes[2,1])
axes[2,1].set_title("Writing by Parental Level of Education")
axes[2,1].tick_params(axis='x', rotation=90)

# Adjust the Layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Report

# %% [markdown]
# ## Gender and Performance
# The first chart shows that the male students have higher math score compared to female students.
# <br>
# Second chart shows that the female students perform well in reading than the male students.
# <br>
# Similarly to reading scores, female students show higher average writing scores compared to the male.

# %% [markdown]
# ## Parental Level of Education and Performaance
# Students whose perents have a bachelor's degree tend to have the highest math score.
# <br> While students with parents who have a master's degree or a bachelor's degree show higher score in both reading and writing.

# %%
# Set the sytle
sns.set(style="darkgrid")

# Initialze the matplotlib figure
fig, axes= plt.subplots(3,2,figsize=(14,18))

# Lunch Vs Scores
sns.barplot(x="Lunch", y="Math score", data=Student_Performance, ax=axes[0,0])
axes[0,0,].set_title("Math Score by Lunch")

sns.barplot(x="Lunch", y="Reading score", data=Student_Performance, ax=axes[0,1])
axes[0,1].set_title("Reading Score by Lunch")

sns.barplot(x="Lunch", y="Writing score", data=Student_Performance, ax=axes[1,0])
axes[1,0].set_title("Writing Score by Lunch")

# Test preparation course  vs Scores
sns.barplot(x="Test preparation course", y="Math score", data=Student_Performance, ax=axes[1,1])
axes[1,1].set_title("Math Score by Test preparation course ")
axes[1,1].tick_params(axis='x', rotation=90)

sns.barplot(x="Test preparation course", y="Reading score", data=Student_Performance, ax=axes[2,0])
axes[2,0].set_title("Reading Score by Test preparation course ")
axes[2,0].tick_params(axis='x', rotation=90)

sns.barplot(x="Test preparation course", y="Writing score", data=Student_Performance, ax=axes[2,1])
axes[2,1].set_title("Writing by Test preparation course ")
axes[2,1].tick_params(axis='x', rotation=90)

# Adjust the Layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Lunch and Performance
# Students who recieve standard lunch have higher scores in all the subjects compared to those with free/reduced lunch.

# %% [markdown]
# ### Test Preparation and Performance
# Students who have completed the test preparation course generally score higher in all courses than those who have not

# %% [markdown]
# # Conclusion
# 1. Male students tend to perform better in math, while female students perform well in both reading and writing courses.
# <br>
# 2. Higher parental education levels correlate with better student performance across all subjects.
# <br>
# 3. Students with standard lunch perform better in math, reading, and writing.
# <br>
# 4. Test preparation courses positively affect the performance in math, reading, and writing.

# %% [markdown]
# # Recommendations
# Implement targeted teaching strategies to support male students in reading and writing and encourage female students to engage more in math through supportive learning and environments.
# <br>
# Promote test preparation courses to all students to improve their academic performances.
